# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../')

# %% [markdown]
# ## 1) applying interpolation

# %%
from core.Interpolate import Interpolation

# %%
from core.image import Image

# %%
img = Image('../Images/cameraman.tif')
scale = 4
img.display()
img.data.shape
# Out:
# (256, 256)

# %%
from core.image import ImageProperties

ImageProperties.histogram(img)
ImageProperties.summary(img)
# Out:
# {'filename': '../Images/cameraman.tif',
#  'image_tensor shape': (256, 256),
#  'brightness': 118.7244873046875,
#  'contrast': 62.34123968732711,
#  'range': (7, 253),
#  'aspect_ratio': (256, 256),
#  'std_deviation': 62.34123968732711,
#  'skewness': -0.7380750505723508}

# %%
img.data.ravel().shape
# Out:
# (65536,)

# %%
img2=Interpolation.decimation(img, 2)

# %%
img2.display()

# %%
img2.data.shape
# Out:
# (128, 128)

# %%
ImageProperties.histogram(img2)
ImageProperties.summary(img2)
# Out:
# {'filename': None,
#  'image_tensor shape': (128, 128),
#  'brightness': 118.618896484375,
#  'contrast': 62.3105734825765,
#  'range': (7, 250),
#  'aspect_ratio': (128, 128),
#  'std_deviation': 62.3105734825765,
#  'skewness': -0.7361668369487401}

# %%
imgnn = Interpolation.nearest_neighbor(img2, scale)
imgnn.display()

# %%
ImageProperties.histogram(imgnn)
ImageProperties.summary(imgnn)
# Out:
# {'filename': None,
#  'image_tensor shape': (512, 512),
#  'brightness': 118.618896484375,
#  'contrast': 62.3105734825765,
#  'range': (7, 250),
#  'aspect_ratio': (512, 512),
#  'std_deviation': 62.3105734825765,
#  'skewness': -0.7361668369487399}

# %%
imgb = Interpolation.bilinear(img2, scale)
imgb.display()

# %%
ImageProperties.histogram(imgb)
ImageProperties.summary(imgb)
# Out:
# {'filename': None,
#  'image_tensor shape': (512, 512),
#  'brightness': 116.5267686843872,
#  'contrast': 61.945333489287734,
#  'range': (0.0, 250.0),
#  'aspect_ratio': (512, 512),
#  'std_deviation': 61.945333489287734,
#  'skewness': -0.7247239104096616}

# %%
imgc = Interpolation.bicubic(img2, scale)
imgc.display()

# %%
ImageProperties.histogram(imgc)
ImageProperties.summary(imgc)
# Out:
# {'filename': None,
#  'image_tensor shape': (512, 512),
#  'brightness': 118.4129963517189,
#  'contrast': 61.363549800275734,
#  'range': (-16.14794921875, 261.84375),
#  'aspect_ratio': (512, 512),
#  'std_deviation': 61.363549800275734,
#  'skewness': -0.7556158685468343}

# %% [markdown]
# ## 2) applying image filter and histogram on interpolations

# %%
from core.image import ImageFilters
ImageFilters.edge_detection(img).display()
ImageFilters.edge_detection(img2).display()
ImageFilters.edge_detection(imgnn).display()
ImageFilters.edge_detection(imgb).display()
ImageFilters.edge_detection(imgc).display()
