# %%
from image import Image

# %%
img = Image('../Images/cameraman.tif')
img.display()

# %%
img.data= img.data*2

# %%
from image import ImageProperties
ImageProperties.range(img)
# Out:
# (0, 252)

# %%
img.display()
